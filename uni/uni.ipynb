# %%
import pandas as pd

cwurData = pd.read_csv("cwurData.csv",sep=",")
shanghaiData = pd.read_csv("shanghaiData.csv", sep=",")
timesData = pd.read_csv("timesData.csv", sep=",")
eesData = pd.read_csv("education_expenditure_supplementary_data.csv", engine='python', sep=",")
easData = pd.read_csv("educational_attainment_supplementary_data.csv", sep=",")
sacData = pd.read_csv("school_and_country_table.csv", sep=",")

# %% [markdown]
# ## Center for World University Rankings 2012 - 2015
# Le fichier cwur contient le classement Center for World University Rankings des meilleures universités de l'année 2012 à 2015, définis par 7 indicateurs :
#
# 1) Quality of Education, measured by the number of a university's alumni who have won major academic distinctions relative to the university's size (25%)
# 2) Alumni Employment, measured by the number of a university's alumni who have held top executive positions at the world's largest companies relative to the university's size (25%)
# 3) Quality of Faculty, measured by the number of faculty members who have won major academic distinctions (10%)
# + Research Performance:
# 4) Research Output, measured by the total number of research papers (10%)
# 5) High-Quality Publications, measured by the number of research papers appearing in top-tier journals (10%)
# 6) Influence, measured by the number of research papers appearing in highly-influential journals (10%)
# 7) Citations, measured by the number of highly-cited research papers (10%)

# %%
cwurData.head()
# Out:
#    world_rank                            institution         country  \
# 0           1                     Harvard University             USA
# 1           2  Massachusetts Institute of Technology             USA
# 2           3                    Stanford University             USA
# 3           4                University of Cambridge  United Kingdom
# 4           5     California Institute of Technology             USA
#
#    national_rank  quality_of_education  alumni_employment  quality_of_faculty  \
# 0              1                     7                  9                   1
# 1              2                     9                 17                   3
# 2              3                    17                 11                   5
# 3              1                    10                 24                   4
# 4              4                     2                 29                   7
#
#    publications  influence  citations  broad_impact  patents   score  year
# ...

# %% [markdown]
# ## Classement de Shanghai de l'année 2005 à 2015
#
# Ce fichier comprend le classement de Shanghai de 2005 à 2015, défini selon les indicateurs suivants :
#
# Universities are ranked by several academic or research performance indicators, including
# 1. alumni and staff winning Nobel Prizes and Fields Medals,
# 2. highly cited researchers,
# 3. papers published in Nature and Science,
# 4. papers indexed in major citation indices,
# 5. and the per capita academic performance of an institution.

# %%
shanghaiData.head()
# Out:
#   world_rank                              university_name national_rank  \
# 0          1                           Harvard University             1
# 1          2                      University of Cambridge             1
# 2          3                          Stanford University             2
# 3          4           University of California, Berkeley             3
# 4          5  Massachusetts Institute of Technology (MIT)             4
#
#    total_score  alumni  award   hici     ns    pub   pcp  year
# 0        100.0   100.0  100.0  100.0  100.0  100.0  72.4  2005
# 1         73.6    99.8   93.4   53.3   56.6   70.9  66.9  2005
# 2         73.4    41.1   72.2   88.5   70.9   72.3  65.0  2005
# 3         72.8    71.8   76.0   69.4   73.9   72.2  52.7  2005
# 4         70.1    74.0   80.6   66.7   65.8   64.3  53.0  2005

# %% [markdown]
# ## Classement Times 2011 - 2016
#
# Ce fichier comprend le classement Times des universités de 2005 à 2015, défini selon les indicateurs suivants :
#
# 1. Teaching (the learning environment): 30%
# 2. Research (volume, income and reputation): 30%
# 3. Citations (research influence): 30%
# 4. International outlook (staff, students, research): 7.5%
# 5. Industry income (knowledge transfer): 2.5%

# %%
timesData.head()
# Out:
#   world_rank                        university_name                   country  \
# 0          1                     Harvard University  United States of America
# 1          2     California Institute of Technology  United States of America
# 2          3  Massachusetts Institute of Technology  United States of America
# 3          4                    Stanford University  United States of America
# 4          5                   Princeton University  United States of America
#
#    teaching international  research  citations income total_score  \
# 0      99.7          72.4      98.7       98.8   34.5        96.1
# 1      97.7          54.6      98.0       99.9   83.7        96.0
# 2      97.8          82.3      91.4       99.9   87.5        95.6
# 3      98.3          29.5      98.1       99.2   64.3        94.3
# 4      90.9          70.3      95.4       99.9      -        94.2
#
#   num_students  student_staff_ratio international_students female_male_ratio  \
# ...

# %% [markdown]
# ## education expenditure supplementary data
# Dépenses publiques d'éducation pour chaque pays de l'OCDE (pour le public : toutes institutions confondues, institutions élémentaires et secondaires, études supérieures ; pareil pour le privé ; pareil pour le total public et privé)

# %%
eesData.head()
# Out:
#         country     institute_type direct_expenditure_type  1995  2000  2005  \
# 0  OECD Average  All Institutions                   Public   4.9   4.9   5.0
# 1     Australia  All Institutions                   Public   4.5   4.6   4.3
# 2       Austria  All Institutions                   Public   5.3   5.4   5.2
# 3       Belgium  All Institutions                   Public   5.0   5.1   5.8
# 4        Canada  All Institutions                   Public   5.8   5.2   4.8
#
#    2009  2010  2011
# 0   5.4   5.4   5.3
# 1   4.5   4.6   4.3
# 2   5.7   5.6   5.5
# 3   6.4   6.4   6.4
# 4   5.0   5.2   NaN

# %% [markdown]
# ## educational attainment supplementary data
# Données détaillées sur le niveau d'études de la population pour chaque pays (Barro-Lee : 1985,1990,1995,2000,2005,2010) + UIS (années différentes selon les pays)

# %%
easData.head()
# Out:
#   country_name                                        series_name  1985  1986  \
# 0  Afghanistan  Barro-Lee: Average years of primary schooling,...  0.33   NaN
# 1  Afghanistan  Barro-Lee: Average years of primary schooling,...  1.03   NaN
# 2  Afghanistan  Barro-Lee: Average years of primary schooling,...  0.83   NaN
# 3  Afghanistan  Barro-Lee: Average years of primary schooling,...  2.34   NaN
# 4  Afghanistan  Barro-Lee: Average years of primary schooling,...  0.54   NaN
#
#    1987  1990  1991  1992  1993  1995  ...  2005  2006  2007  2008  2009  \
# 0   NaN  0.44   NaN   NaN   NaN  0.57  ...  0.86   NaN   NaN   NaN   NaN
# 1   NaN  1.26   NaN   NaN   NaN  1.54  ...  2.18   NaN   NaN   NaN   NaN
# 2   NaN  0.95   NaN   NaN   NaN  1.26  ...  1.01   NaN   NaN   NaN   NaN
# 3   NaN  2.22   NaN   NaN   NaN  2.37  ...  2.26   NaN   NaN   NaN   NaN
# 4   NaN  0.92   NaN   NaN   NaN  0.94  ...  2.00   NaN   NaN   NaN   NaN
#
#    2010  2011  2012  2013  2015
# ...

# %% [markdown]
# ## school and country table
# Fichier comprenant toutes les universités et leur pays correspondant issus du classement du Times

# %%
sacData.head()
# Out:
#                              school_name                   country
# 0                     Harvard University  United States of America
# 1     California Institute of Technology  United States of America
# 2  Massachusetts Institute of Technology  United States of America
# 3                    Stanford University  United States of America
# 4                   Princeton University  United States of America
